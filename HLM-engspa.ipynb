# %%
import pickle
import torch
import numpy as np
import pandas as pd
from datasets import load_dataset
from torch.utils.data import TensorDataset, random_split
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

# %% [markdown]
# Install the necessary Libraries before running the code

# %%
import torch
if torch.cuda.is_available():       
    device = torch.device("cuda:0")
    print('There are %d GPU(s) available.' % torch.cuda.device_count())
    print('We will use the GPU:', torch.cuda.get_device_name())
else:
    
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")
# Out:
# There are 3 GPU(s) available.
# We will use the GPU: NVIDIA RTX A5000

# %%
import torch
torch.cuda.set_device(2)
import gc 
gc.collect()
torch.cuda.empty_cache()

# %% [markdown]
# ### Dataset
# The dataset can be downloaded from [SemEval-2020 Task 9: Overview of Sentiment Analysis of Code-Mixed Tweets](https://aclanthology.org/2020.semeval-1.100/) (Patwa et al., SemEval 2020)
# <br>
# Replace the train, validation and test file paths with actual path.

# %%
# from datasets import load_dataset

# data_files = {
#     'train': 'ENHINDATA/train.csv',
#     'validation': 'ENHINDATA/validation.csv',
#     'test': 'ENHINDATA/test.csv'
# }
# dataset = load_dataset('csv', data_files=data_files)
# print(dataset)

# %%
X_train = []
y_train = []
X_eval = []
y_eval = []

# %%
with open('engspa/train.txt',encoding='UTF-8') as rf:
    lines = rf.readlines()
for lin in lines:
    da = lin.split('\t')
    lab = da[1].strip()
    X_train.append(da[0])
    if lab == "neutral":
        y_train.append(0)
    if lab == "positive":
        y_train.append(1)
    if lab == "negative":
        y_train.append(2)

# %%
len(X_train)
# Out:
# 12194

# %%
with open('engspa/validation.txt',encoding='UTF-8') as rf:
    lines = rf.readlines()
for lin in lines:
    da = lin.split('\t')
    lab = da[1].strip()
    X_eval.append(da[0])
    if lab == "neutral":
        y_eval.append(0)
    if lab == "positive":
        y_eval.append(1)
    if lab == "negative":
        y_eval.append(2)

# %%
with open('engspa/test.txt',encoding='UTF-8') as rf:
    lines = rf.readlines()
X_test=[]
y_test = []
for lin in lines:
    da = lin.split('\t')
    # lab = da[1].strip()
    X_test.append(da[0])
    # if lab == "neutral":
    #     y_test.append(0)
    # if lab == "positive":
    #     y_test.append(1)
    # if lab == "negative":
    #     y_test.append(2)

# %%
len(X_test)
# Out:
# 4736

# %% [markdown]
# Replace the llm model and llm tokenizer with the desired decoder only llm model.

# %%
import torch
import torch.nn as nn
from transformers import AutoTokenizer, AutoModel, AutoTokenizer
from peft import get_peft_model, LoraConfig

# Model and tokenizer setup
llm_model_name = 'google/gemma-2-2b'
gpttokenizer = AutoTokenizer.from_pretrained(llm_model_name)
gpttokenizer.add_special_tokens({'pad_token': '[PAD]'})
llmmodel = AutoModel.from_pretrained(llm_model_name, trust_remote_code=True)

# LoRA configuration
lora_config = LoraConfig(
    r=64,  # Rank of the low-rank adaptation
    lora_alpha=32,  # Scaling factor
    lora_dropout=0.05,  # Dropout rate
    target_modules=["q_proj", "v_proj", "k_proj", "o_proj", "down_proj", "gate_proj", "up_proj"] # Target modules for LoRA
)

# Apply LoRA to the model
gptmodel = get_peft_model(llmmodel, lora_config)

# Move the model to the desired GPU
gptmodel.to('cuda:0')
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# PeftModel(
#   (base_model): LoraModel(
#     (model): Gemma2Model(
#       (embed_tokens): Embedding(256000, 2304, padding_idx=0)
#       (layers): ModuleList(
#         (0-25): 26 x Gemma2DecoderLayer(
#           (self_attn): Gemma2SdpaAttention(
#             (q_proj): lora.Linear(
#               (base_layer): Linear(in_features=2304, out_features=2048, bias=False)
#               (lora_dropout): ModuleDict(
#                 (default): Dropout(p=0.05, inplace=False)
#               )
#               (lora_A): ModuleDict(
#                 (default): Linear(in_features=2304, out_features=64, bias=False)
#               )
#               (lora_B): ModuleDict(
#                 (default): Linear(in_features=64, out_features=2048, bias=False)
#               )
#               (lora_embedding_A): ParameterDict()
#               (lora_embedding_B): ParameterDict()
#             )
#             (k_proj): lora.Linear(
#               (base_layer): Linear(in_features=2304, out_features=1024, bias=False)
#               (lora_dropout): ModuleDict(
#                 (default): Dropout(p=0.05, inplace=False)
#               )
#               (lora_A): ModuleDict(
#                 (default): Linear(in_features=2304, out_features=64, bias=False)
#               )
#               (lora_B): ModuleDict(
#                 (default): Linear(in_features=64, out_features=1024, bias=False)
#               )
#               (lora_embedding_A): ParameterDict()
#               (lora_embedding_B): ParameterDict()
#             )
#             (v_proj): lora.Linear(
#               (base_layer): Linear(in_features=2304, out_features=1024, bias=False)
#               (lora_dropout): ModuleDict(
#                 (default): Dropout(p=0.05, inplace=False)
#               )
#               (lora_A): ModuleDict(
#                 (default): Linear(in_features=2304, out_features=64, bias=False)
#               )
#               (lora_B): ModuleDict(
#                 (default): Linear(in_features=64, out_features=1024, bias=False)
#               )
#               (lora_embedding_A): ParameterDict()
#               (lora_embedding_B): ParameterDict()
#             )
#             (o_proj): lora.Linear(
#               (base_layer): Linear(in_features=2048, out_features=2304, bias=False)
#               (lora_dropout): ModuleDict(
#                 (default): Dropout(p=0.05, inplace=False)
#               )
#               (lora_A): ModuleDict(
#                 (default): Linear(in_features=2048, out_features=64, bias=False)
#               )
#               (lora_B): ModuleDict(
#                 (default): Linear(in_features=64, out_features=2304, bias=False)
#               )
#               (lora_embedding_A): ParameterDict()
#               (lora_embedding_B): ParameterDict()
#             )
#             (rotary_emb): Gemma2RotaryEmbedding()
#           )
#           (mlp): Gemma2MLP(
#             (gate_proj): lora.Linear(
#               (base_layer): Linear(in_features=2304, out_features=9216, bias=False)
#               (lora_dropout): ModuleDict(
#                 (default): Dropout(p=0.05, inplace=False)
#               )
#               (lora_A): ModuleDict(
#                 (default): Linear(in_features=2304, out_features=64, bias=False)
#               )
#               (lora_B): ModuleDict(
#                 (default): Linear(in_features=64, out_features=9216, bias=False)
#               )
#               (lora_embedding_A): ParameterDict()
#               (lora_embedding_B): ParameterDict()
#             )
#             (up_proj): lora.Linear(
#               (base_layer): Linear(in_features=2304, out_features=9216, bias=False)
#               (lora_dropout): ModuleDict(
#                 (default): Dropout(p=0.05, inplace=False)
#               )
#               (lora_A): ModuleDict(
#                 (default): Linear(in_features=2304, out_features=64, bias=False)
#               )
#               (lora_B): ModuleDict(
#                 (default): Linear(in_features=64, out_features=9216, bias=False)
#               )
#               (lora_embedding_A): ParameterDict()
#               (lora_embedding_B): ParameterDict()
#             )
#             (down_proj): lora.Linear(
#               (base_layer): Linear(in_features=9216, out_features=2304, bias=False)
#               (lora_dropout): ModuleDict(
#                 (default): Dropout(p=0.05, inplace=False)
#               )
#               (lora_A): ModuleDict(
#                 (default): Linear(in_features=9216, out_features=64, bias=False)
#               )
#               (lora_B): ModuleDict(
#                 (default): Linear(in_features=64, out_features=2304, bias=False)
#               )
#               (lora_embedding_A): ParameterDict()
#               (lora_embedding_B): ParameterDict()
#             )
#             (act_fn): PytorchGELUTanh()
#           )
#           (input_layernorm): Gemma2RMSNorm()
#           (post_attention_layernorm): Gemma2RMSNorm()
#           (pre_feedforward_layernorm): Gemma2RMSNorm()
#           (post_feedforward_layernorm): Gemma2RMSNorm()
#         )
#       )
#       (norm): Gemma2RMSNorm()
#     )
#   )
# )

# %% [markdown]
# Replace the bertmodel and tokenizer with the desired encoder model.

# %%
from transformers import BertTokenizer, BertModel

berttokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-uncased')
bertmodel = BertModel.from_pretrained('bert-base-multilingual-uncased')
bertmodel.to('cuda:0')
# Out:
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(105879, 768, padding_idx=0)
#     (position_embeddings): Embedding(512, 768)
#     (token_type_embeddings): Embedding(2, 768)
#     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0-11): 12 x BertLayer(
#         (attention): BertAttention(
#           (self): BertSdpaSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
#   (pooler): BertPooler(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (activation): Tanh()
#   )
# )

# %%
class Classifier(nn.Module):
    def __init__(self, hidden_size, num_classes):
        super(Classifier, self).__init__()
        self.fc1 = nn.Linear(hidden_size, 768)  # Combine BERT + Gemma embeddings
        self.fc2 = nn.Linear(768, 256)
        self.fc3 = nn.Linear(256, 64)
        self.fc4 = nn.Linear(64, num_classes)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(0.3)

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.fc2(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.fc3(x)
        x = self.relu(x)
        x = self.fc4(x)
        return torch.softmax(x, dim=1)

# %%
num_classes = 3  # For example
classifier = Classifier(bertmodel.config.hidden_size + gptmodel.config.hidden_size, num_classes)
classifier.to('cuda:0')
# Out:
# Classifier(
#   (fc1): Linear(in_features=3072, out_features=768, bias=True)
#   (fc2): Linear(in_features=768, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=64, bias=True)
#   (fc4): Linear(in_features=64, out_features=3, bias=True)
#   (relu): ReLU()
#   (dropout): Dropout(p=0.3, inplace=False)
# )

# %%
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(list(bertmodel.parameters()) + list(gptmodel.parameters()) + list(classifier.parameters()), lr=5e-4)

# %% [markdown]
# ## Test & Validation

# %%
from sklearn.metrics import f1_score
def predict(bertmodel, gptmodel):
    n = len(X_eval)
    bertmodel.eval()
    gptmodel.eval()
    correct = 0
    y_pred = []
    y_act = []
    for j in tqdm(range(n)):
        inputsgpt = gpttokenizer(X_eval[j], return_tensors="pt")
        inputsbert = berttokenizer(X_eval[j], return_tensors="pt")
        
        with torch.no_grad():
            outputsbert = bertmodel(**(inputsbert.to('cuda:0')))
            outputsgpt = gptmodel(**(inputsgpt.to('cuda:0')))
        bert_hidden_states = outputsbert[0].mean(dim = 1)
        gpt_hidden_states = outputsgpt[0].mean(dim = 1)
        
        
        representation = torch.cat([bert_hidden_states, gpt_hidden_states], dim=1)
        # representation = representation.unsqueeze(1)    
        logits = classifier(representation)
        print(logits)
        y_pred.append(torch.argmax(logits, dim=1).item())
        if torch.argmax(logits, dim=1)==y_eval[j]:
            correct += 1
        y_act.append(y_eval[j])
    print('Validation Accuracy: ', correct/n)
    print('Validation F1 Score: ', f1_score(y_pred,y_act, average='weighted'))

# %%
def test(bertmodel, gptmodel):
    n = len(X_test)
    bertmodel.eval()
    gptmodel.eval()
    correct = 0
    y_pred = []
    for j in tqdm(range(n)):
        inputsgpt = gpttokenizer(X_test[j], return_tensors="pt")
        inputsbert = berttokenizer(X_test[j], return_tensors="pt")
        
        with torch.no_grad():
            outputsbert = bertmodel(**(inputsbert.to('cuda:0')))
            outputsgpt = gptmodel(**(inputsgpt.to('cuda:0')))
        bert_hidden_states = outputsbert[0].mean(dim = 1)
        gpt_hidden_states = outputsgpt[0].mean(dim = 1)
        representation = torch.cat([bert_hidden_states, gpt_hidden_states], dim=1)
            
        logits = classifier(representation)
        k = torch.argmax(logits, dim=1)
        y_pred.append(k)
    y_pred = [t.item() for t in y_pred]
    return y_pred
            #correct += 1
    #print('Validation Accuracy: ', correct/n)

# %% [markdown]
# ## Training stochastic

# %%
from tqdm import tqdm
def train(bertmodel, gptmodel):
    for i in range(3):
        running_loss = 0
        n = len(X_train)
        for j in tqdm(range(n)):
            inputsgpt = gpttokenizer(X_train[j], return_tensors="pt")
            
            inputsbert = berttokenizer(X_train[j], return_tensors="pt")

            outputsbert = bertmodel(**(inputsbert.to('cuda:0')))
            bert_hidden_states = outputsbert[0].mean(dim=1)
            outputsgpt = gptmodel(**(inputsgpt.to('cuda:0')))
            
            gpt_hidden_states = outputsgpt[0].mean(dim=1)
           
            representation = torch.cat([bert_hidden_states, gpt_hidden_states], dim=1)
            
            logits = classifier(representation)
            target = torch.tensor(y_train[j]).to('cuda:0')
            target = target.reshape(-1)
            loss = criterion(logits, target)

            running_loss += loss.item()

            # Backpropagate the gradients
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        print("------------\nEPOCH :", i )
        predict(bertmodel, gptmodel)
        y_pred = test(bertmodel,gptmodel)
        with open('results_{}.txt'.format(i), 'w') as file:
            for x in y_pred:
                if x == 0:
                    file.write('neutral')
                elif x == 1:
                    file.write('positive')
                else:
                    file.write('negative')

# %% [markdown]
# ## batch gradient descent

# %%
import torch
from tqdm import tqdm
from sklearn.metrics import f1_score

batch_size = 2  

def batch_tokenize(tokenizer, texts):
    # Tokenize a list of texts and return tensors on CUDA device
    # print(tokenizer(texts, return_tensors='pt', padding=True, truncation=True))
    return tokenizer(texts, return_tensors='pt', padding=True, truncation=True)

def predict(bertmodel, gptmodel):
    bertmodel.eval()
    gptmodel.eval()

    y_pred = []
    y_act = []

    n = len(X_eval)
    for i in tqdm(range(0, n, batch_size)):
        batch_texts = X_eval[i:i+batch_size]
        batch_labels = y_eval[i:i+batch_size]

        inputsbert = batch_tokenize(berttokenizer, batch_texts)
        inputsgpt = batch_tokenize(gpttokenizer, batch_texts)

        with torch.no_grad():
            outputsbert = bertmodel(**inputsbert)
            outputsgpt = gptmodel(**inputsgpt)

        bert_hidden_states = outputsbert.last_hidden_state.mean(dim=1)  # (batch_size, hidden_dim)
        gpt_hidden_states = outputsgpt.last_hidden_state.mean(dim=1)    # (batch_size, hidden_dim)

        representation = torch.cat([bert_hidden_states, gpt_hidden_states], dim=1)  # (batch_size, 2*hidden_dim)

        logits = classifier(representation)  # (batch_size, num_classes)
        preds = torch.argmax(logits, dim=1).cpu().tolist()

        y_pred.extend(preds)
        y_act.extend(batch_labels)

    correct = sum([p == a for p, a in zip(y_pred, y_act)])
    accuracy = correct / n
    f1 = f1_score(y_act, y_pred, average='weighted')

    print(f'Validation Accuracy: {accuracy:.4f}')
    print(f'Validation F1 Score: {f1:.4f}')


def train(bertmodel, gptmodel):
    bertmodel.train()
    gptmodel.train()

    n = len(X_train)
    for epoch in range(3):
        running_loss = 0.0

        for i in tqdm(range(0, n, batch_size)):
            batch_texts = X_train[i:i+batch_size]
            batch_labels = y_train[i:i+batch_size]
            
            inputsbert = batch_tokenize(berttokenizer, batch_texts)
            inputsgpt = batch_tokenize(gpttokenizer, batch_texts)
           
            outputsbert = bertmodel(**(inputsbert.to('cuda:0')))
            outputsgpt = gptmodel(**(inputsgpt.to('cuda:0')))

            bert_hidden_states = outputsbert.last_hidden_state.mean(dim=1)
            gpt_hidden_states = outputsgpt.last_hidden_state.mean(dim=1)

            representation = torch.cat([bert_hidden_states, gpt_hidden_states], dim=1)

            logits = classifier(representation)

            target = torch.tensor(batch_labels).to('cuda:0')
            loss = criterion(logits, target)

            running_loss += loss.item() * len(batch_labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        avg_loss = running_loss / n
        print(f"------------\nEPOCH : {epoch} | Average Loss: {avg_loss:.4f}")

        predict(bertmodel, gptmodel)

        y_pred = test(bertmodel, gptmodel)
        with open(f'results_{epoch}.txt', 'w') as file:
            for x in y_pred:
                if x == 0:
                    file.write('neutral\n')
                elif x == 1:
                    file.write('positive\n')
                else:
                    file.write('negative\n')

# %%
train(bertmodel, gptmodel)
# Out:
#   0%|                                                  | 0/6097 [00:00<?, ?it/s]/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [418,0,0], thread: [32,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [418,0,0], thread: [33,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [418,0,0], thread: [34,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [418,0,0], thread: [35,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [418,0,0], thread: [36,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [418,0,0], thread: [37,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [418,0,0], thread: [38,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [418,0,0], thread: [39,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [418,0,0], thread: [40,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [418,0,0], thread: [41,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [418,0,0], thread: [42,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [418,0,0], thread: [43,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [418,0,0], thread: [44,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [418,0,0], thread: [45,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [418,0,0], thread: [46,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [418,0,0], thread: [47,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [418,0,0], thread: [48,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [418,0,0], thread: [49,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [418,0,0], thread: [50,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [418,0,0], thread: [51,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [418,0,0], thread: [52,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [418,0,0], thread: [53,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [418,0,0], thread: [54,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [418,0,0], thread: [55,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [418,0,0], thread: [56,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [418,0,0], thread: [57,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [418,0,0], thread: [58,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [418,0,0], thread: [59,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [418,0,0], thread: [60,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [418,0,0], thread: [61,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [418,0,0], thread: [62,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [418,0,0], thread: [63,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [424,0,0], thread: [96,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [424,0,0], thread: [97,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [424,0,0], thread: [98,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [424,0,0], thread: [99,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [424,0,0], thread: [100,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [424,0,0], thread: [101,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [424,0,0], thread: [102,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [424,0,0], thread: [103,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [424,0,0], thread: [104,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [424,0,0], thread: [105,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [424,0,0], thread: [106,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [424,0,0], thread: [107,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [424,0,0], thread: [108,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [424,0,0], thread: [109,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [424,0,0], thread: [110,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [424,0,0], thread: [111,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [424,0,0], thread: [112,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [424,0,0], thread: [113,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [424,0,0], thread: [114,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [424,0,0], thread: [115,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [424,0,0], thread: [116,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [424,0,0], thread: [117,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [424,0,0], thread: [118,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [424,0,0], thread: [119,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [424,0,0], thread: [120,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [424,0,0], thread: [121,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [424,0,0], thread: [122,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [424,0,0], thread: [123,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [424,0,0], thread: [124,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [424,0,0], thread: [125,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [424,0,0], thread: [126,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [424,0,0], thread: [127,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [64,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [65,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [66,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [67,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [68,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [69,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [70,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [71,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [72,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [73,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [74,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [75,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [76,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [77,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [78,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [79,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [80,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [81,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [82,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [83,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [84,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [85,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [86,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [87,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [88,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [89,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [90,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [91,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [92,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [93,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [94,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [95,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [32,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [33,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [34,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [35,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [36,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [37,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [38,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [39,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [40,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [41,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [42,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [43,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [44,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [45,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [46,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [47,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [48,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [49,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [50,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [51,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [52,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [53,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [54,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [55,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [56,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [57,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [58,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [59,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [60,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [61,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [62,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [63,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [0,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [1,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [2,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [3,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [4,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [5,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [6,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [7,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [8,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [9,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [10,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [11,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [12,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [13,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [14,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [15,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [16,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [17,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [18,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [19,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [20,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [21,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [22,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [23,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [24,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [25,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [26,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [27,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [28,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [29,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [30,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [31,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [0,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [1,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [2,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [3,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [4,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [5,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [6,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [7,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [8,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [9,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [10,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [11,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [12,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [13,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [14,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [15,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [16,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [17,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [18,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [19,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [20,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [21,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [22,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [23,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [24,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [25,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [26,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [27,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [28,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [29,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [30,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [31,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [32,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [33,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [34,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [35,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [36,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [37,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [38,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [39,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [40,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [41,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [42,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [43,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [44,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [45,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [46,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [47,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [48,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [49,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [50,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [51,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [52,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [53,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [54,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [55,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [56,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [57,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [58,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [59,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [60,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [61,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [62,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [63,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [0,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [1,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [2,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [3,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [4,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [5,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [6,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [7,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [8,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [9,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [10,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [11,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [12,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [13,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [14,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [15,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [16,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [17,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [18,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [19,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [20,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [21,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [22,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [23,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [24,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [25,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [26,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [27,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [28,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [29,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [30,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [398,0,0], thread: [31,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [96,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [97,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [98,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [99,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [100,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [101,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [102,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [103,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [104,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [105,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [106,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [107,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [108,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [109,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [110,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [111,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [112,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [113,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [114,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [115,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [116,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [117,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [118,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [119,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [120,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [121,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [122,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [123,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [124,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [125,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [126,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [127,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [32,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [33,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [34,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [35,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [36,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [37,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [38,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [39,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [40,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [41,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [42,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [43,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [410,0,0], thread: [44,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ...
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [51,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [52,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [53,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [54,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [55,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [56,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [57,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [58,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [59,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [60,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [61,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [62,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [468,0,0], thread: [63,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [0,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [1,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [2,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [3,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [4,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [5,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [6,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [7,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [8,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [9,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [10,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [11,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [12,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [13,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [14,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [15,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [16,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [17,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [18,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [19,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [20,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [21,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [22,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [23,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [24,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [25,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [26,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [27,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [28,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [29,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [30,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [404,0,0], thread: [31,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [474,0,0], thread: [96,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [474,0,0], thread: [97,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [474,0,0], thread: [98,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [474,0,0], thread: [99,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [474,0,0], thread: [100,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [474,0,0], thread: [101,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [474,0,0], thread: [102,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [474,0,0], thread: [103,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [474,0,0], thread: [104,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [474,0,0], thread: [105,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [474,0,0], thread: [106,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [474,0,0], thread: [107,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [474,0,0], thread: [108,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [474,0,0], thread: [109,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [474,0,0], thread: [110,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [474,0,0], thread: [111,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [474,0,0], thread: [112,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [474,0,0], thread: [113,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [474,0,0], thread: [114,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [474,0,0], thread: [115,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [474,0,0], thread: [116,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [474,0,0], thread: [117,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [474,0,0], thread: [118,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [474,0,0], thread: [119,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [474,0,0], thread: [120,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [474,0,0], thread: [121,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [474,0,0], thread: [122,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [474,0,0], thread: [123,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [474,0,0], thread: [124,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [474,0,0], thread: [125,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [474,0,0], thread: [126,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [474,0,0], thread: [127,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
#   0%|                                                  | 0/6097 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 train(bertmodel, gptmodel)
#
# Cell In[21], line 66, in train(bertmodel, gptmodel)
#      63 inputsgpt = batch_tokenize(gpttokenizer, batch_texts)
#      65 outputsbert = bertmodel(**(inputsbert.to('cuda:0')))
# ---> 66 outputsgpt = gptmodel(**(inputsgpt.to('cuda:0')))
#      68 bert_hidden_states = outputsbert.last_hidden_state.mean(dim=1)
#      69 gpt_hidden_states = outputsgpt.last_hidden_state.mean(dim=1)
#
# File /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /usr/local/lib/python3.11/dist-packages/peft/peft_model.py:563, in PeftModel.forward(self, *args, **kwargs)
#     561 with self._enable_peft_forward_hooks(*args, **kwargs):
#     562     kwargs = {k: v for k, v in kwargs.items() if k not in self.special_peft_forward_args}
# --> 563     return self.get_base_model()(*args, **kwargs)
#
# File /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /usr/local/lib/python3.11/dist-packages/transformers/models/gemma2/modeling_gemma2.py:871, in Gemma2Model.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#     868     inputs_embeds = self.embed_tokens(input_ids)
#     870 if cache_position is None:
# --> 871     cache_position = torch.arange(0, inputs_embeds.shape[1], device=inputs_embeds.device)
#     873 if position_ids is None:
#     874     position_ids = cache_position.unsqueeze(0)
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %% [markdown]
# predict function prints the test F1 score

# %%
 predict(bertmodel, gptmodel)
# Out:
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 16.38it/s]
# tensor([[1.0000e+00, 6.3382e-16, 1.9429e-16]], device='cuda:0',
#        grad_fn=<SoftmaxBackward0>)
# tensor([[1.0000e+00, 1.9566e-18, 3.5129e-19]], device='cuda:0',
#        grad_fn=<SoftmaxBackward0>)
# tensor([[1.0000e+00, 3.0373e-16, 4.8170e-16]], device='cuda:0',
#        grad_fn=<SoftmaxBackward0>)
# Validation Accuracy:  0.0
# Validation F1 Score:  0.0

# %%
y_pred = test(bertmodel,gptmodel)
# Out:
#   4%|█▋                                      | 201/4736 [00:10<03:51, 19.57it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 y_pred = test(bertmodel,gptmodel)
#
# Cell In[39], line 13, in test(bertmodel, gptmodel)
#      11 with torch.no_grad():
#      12     outputsbert = bertmodel(**(inputsbert.to('cuda:0')))
# ---> 13     outputsgpt = gptmodel(**(inputsgpt.to('cuda:0')))
#      14 bert_hidden_states = outputsbert[0].mean(dim = 1)
#      15 gpt_hidden_states = outputsgpt[0].mean(dim = 1)
#
# File /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /usr/local/lib/python3.11/dist-packages/peft/peft_model.py:563, in PeftModel.forward(self, *args, **kwargs)
#     561 with self._enable_peft_forward_hooks(*args, **kwargs):
#     562     kwargs = {k: v for k, v in kwargs.items() if k not in self.special_peft_forward_args}
# --> 563     return self.get_base_model()(*args, **kwargs)
#
# File /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /usr/local/lib/python3.11/dist-packages/transformers/models/gemma2/modeling_gemma2.py:908, in Gemma2Model.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#     897     layer_outputs = self._gradient_checkpointing_func(
#     898         decoder_layer.__call__,
#     899         hidden_states,
#    (...)
#     905         cache_position,
#     906     )
#     907 else:
# --> 908     layer_outputs = decoder_layer(
#     909         hidden_states,
#     910         attention_mask=causal_mask,
#     911         position_ids=position_ids,
#     912         past_key_value=past_key_values,
#     913         output_attentions=output_attentions,
#     914         use_cache=use_cache,
#     915         cache_position=cache_position,
#     916     )
#     918 hidden_states = layer_outputs[0]
#     920 if output_attentions:
#
# File /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /usr/local/lib/python3.11/dist-packages/transformers/models/gemma2/modeling_gemma2.py:664, in Gemma2DecoderLayer.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, cache_position)
#     662 residual = hidden_states
#     663 hidden_states = self.pre_feedforward_layernorm(hidden_states)
# --> 664 hidden_states = self.mlp(hidden_states)
#     665 hidden_states = self.post_feedforward_layernorm(hidden_states)
#     666 hidden_states = residual + hidden_states
#
# File /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /usr/local/lib/python3.11/dist-packages/transformers/models/gemma2/modeling_gemma2.py:164, in Gemma2MLP.forward(self, x)
#     163 def forward(self, x):
# --> 164     return self.down_proj(self.act_fn(self.gate_proj(x)) * self.up_proj(x))
#
# File /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /usr/local/lib/python3.11/dist-packages/peft/tuners/lora/layer.py:497, in Linear.forward(self, x, *args, **kwargs)
#     495     result = self.base_layer(x, *args, **kwargs)
#     496 else:
# --> 497     result = self.base_layer(x, *args, **kwargs)
#     498     torch_result_dtype = result.dtype
#     499     for active_adapter in self.active_adapters:
#
# File /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /usr/local/lib/python3.11/dist-packages/torch/nn/modules/linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
with open("sa_spa_eng", "w") as writer:
        writer.write('\n'.join(y_pred))
